# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\SUYDUBEY\\Documents\\Data Science\\Sample datasets\\Titanic.csv")

# %%
#Exploring the data

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
data.shape
# Out:
# (418, 12)

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.nunique()
# Out:
# PassengerId    418
# Survived         2
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
data['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['Pclass'].unique()
# Out:
# array([3, 2, 1], dtype=int64)

# %%
#Cleaning the data

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#removing the parch column

# %%
titanic = data.drop(['Parch'],axis=1)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp   Ticket  \
# 0                              Kelly, Mr. James    male  34.5      0   330911
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1   363272
# 2                     Myles, Mr. Thomas Francis    male  62.0      0   240276
# 3                              Wirz, Mr. Albert    male  27.0      0   315154
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1  3101298
#
#       Fare Cabin Embarked
# 0   7.8292   NaN        Q
# 1   7.0000   NaN        S
# 2   9.6875   NaN        Q
# 3   8.6625   NaN        S
# 4  12.2875   NaN        S

# %%
#relationship analysis

# %%
corelation = titanic.corr()

# %%
sns.pairplot(titanic)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp   Ticket  \
# 0                              Kelly, Mr. James    male  34.5      0   330911
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1   363272
# 2                     Myles, Mr. Thomas Francis    male  62.0      0   240276
# 3                              Wirz, Mr. Albert    male  27.0      0   315154
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1  3101298
#
#       Fare Cabin Embarked
# 0   7.8292   NaN        Q
# 1   7.0000   NaN        S
# 2   9.6875   NaN        Q
# 3   8.6625   NaN        S
# 4  12.2875   NaN        S

# %%
sns.relplot(x='Pclass' , y='Fare',data=titanic)

# %%
sns.distplot(titanic['Age'],bins=10)
# Out:
# C:\Users\SUYDUBEY\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>
